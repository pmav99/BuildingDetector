# %% [markdown]
# # Creating Python Modules
# In this notebook, I will test out some of the code written previously by saving them in separate modules and importing those. The goal is to clean up and save space in future IPython notebooks.

# %%
from color_histograms import *
from utils import *
import IPython.display
import cv2

# %matplotlib inline

# %%
imageDir = '../images/'
test1fn = imageDir + 'test_images/test1.png'
IPython.display.Image(test1fn)

# %% [markdown]
# ### Testing color histogram

# %%
test1 = cv2.imread(test1fn)
plot_color_hist(test1, bins=8)

# %% [markdown]
# ### Testing template matching

# %% [markdown]
# First let's just test a function that returns the result of template-matching as an array, since we will need to use such a function to get color histogram features later for classifying images and parts of images.

# %%
temp1fn = imageDir + 'templates/template1.png'
result1 = match_template(test1fn, temp1fn)

# %% [markdown]
# Next, let's try to template-match an image, threshold the result, and write an output image that shows where the original image satisfies the template threshold.

# %%
out1fn = imageDir + 'output_images/test1Neal.png'
write_thresholded(test1fn, temp1fn, out1fn, threshold=0.1, color=(0,255,0))
IPython.display.Image(out1fn)

# %% [markdown]
# Finally, let's try to process a whole batch of images at once with the same template and threshold, writing them all to output images in the given output directory.

# %%
inputDir = imageDir + 'test_images/'
outputDir = imageDir + 'output_images/'
batch_write(inputDir, temp1fn, outputDir, suffix='Neal')
# Out:
# Template-matched 10 images in 0.569908857346 seconds.

# %%
inputDir = imageDir + 'DHS_in/'
outputDir = imageDir + 'DHS_out/'
batch_write(inputDir, temp1fn, outputDir, suffix='Neal')
# Out:
# Template-matched 158 images in 10.9907929897 seconds.

# %% [markdown]
# ### More testing of template matching
# In notebook 9, I try changing the threshold for template matching from 0.1 and it causes the function to fail.

# %%
test3Fn = imageDir + 'test_images/test3.png'

# %%
IPython.display.Image(test3Fn)

# %%
out3Fn = imageDir + 'output_images/test3.png'
write_thresholded(test3Fn, temp1fn, out3Fn, threshold=0.05, color=(0,255,0))
IPython.display.Image(out3Fn)

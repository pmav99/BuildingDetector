# %% [markdown]
# # Segmenting Satellite Images
# In this notebook, I will try to figure out how to segment satellite images. If I can segment out the buildings, then maybe I can use color histograms to classify different segments as building/non-building.
#
# Let's first start by following the same steps given in the tutorial. I'll choose a satellite image that seems like it might give good segmentation results.

# %% [markdown]
# ### Choosing an image

# %%
import IPython.display

# %%
imageDir = '../images/'
imagePath = imageDir + 'test_images/test2.png'
IPython.display.Image(filename=imagePath)

# %% [markdown]
# ### Perform binary thresholding
# We will use Otsu's method to perform clustering-based thresholding, separating the pixels in the grayscale image into two classes.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Load the image
img = cv2.imread(imagePath)
plt.imshow(img)

# %%
# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap=plt.cm.Greys_r)

# %%
# Threshold using Otsu's binarization
ret, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + \
                           cv2.THRESH_OTSU)
plt.imshow(thresh, cmap=plt.cm.Greys_r)

# %% [markdown]
# ## FAIL
# Clearly, performing binary segmentation on satellite images isn't going to work, we'll have to try something else.
